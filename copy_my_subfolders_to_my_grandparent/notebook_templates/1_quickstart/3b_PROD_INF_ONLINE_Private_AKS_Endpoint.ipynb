# %% [markdown]
# # PRODUCTION phase: About this notebook
# - Purpose: Creates 1 AKS webservice, to serve the model as an ONLINE endpoint
#     - `AKS ONLINE Webservice:` Fetches the best trained model, Deployes that on an `AKS cluster`, always up and running, ready to be pinged and return results (via REST / Swagger, or Python SDK)
#
# ## DETAILS - about this notebook and the 2 pipelines, generated
# - 1) `Initiates ESMLProject` and sets `active model` and `active date folder`:
# - 2) `DEPLOY & SERVER: Fetched the BEST MODEL, and deploys on AKS`
# - 3) `Smoke testing: Fetches some data and calls the webservice` (smoke testing purpose - see that it works...)
#     - Gets test data
#     - Calls webservice, which both returns data via REST call, and ESML optionally also saves the returned result to datalake

# %% [markdown]
# # Login / Switch DEV_TEST_PROD environment (1-timer)

# %% [markdown]
# import sys
# sys.path.insert(0, "../azure-enterprise-scale-ml/esml/common/")
# from azureml.core.authentication import InteractiveLoginAuthentication
# from esml import ESMLProject
#
# p = ESMLProject() # Will search in ROOT for your copied SETTINGS folder '../settings/model/active/active_scoring_in_folder.json',
# p.dev_test_prod="dev"
# auth = InteractiveLoginAuthentication(tenant_id = p.tenant)
# #auth = InteractiveLoginAuthentication(force=True, tenant_id = p.tenant)
# ws, config_name = p.authenticate_workspace_and_write_config(auth)

# %% [markdown]
# # 1) `Initiates ESMLProject` and sets `active model` and `active date folder`:

# %%
import sys
sys.path.insert(0, "../azure-enterprise-scale-ml/")
from esmlrt.interfaces.iESMLController import IESMLController
sys.path.insert(0, "../azure-enterprise-scale-ml/esml/common/")
from esml import ESMLProject
import pandas as pd

p = ESMLProject() # Will search in ROOT for your copied SETTINGS folder '../settings/model/active/active_scoring_in_folder.json',
p.active_model = 11
p.inference_mode = False
p.ws = p.get_workspace_from_config() #2) Load DEV or TEST or PROD Azure ML Studio workspace
p.verbose_logging = False
# Out:
# Using lake_settings.json with ESML version 1.4 - Models array support including LABEL

# %%
#print("NB! The below command you only need to run 1 time a day - then you can disable this cell / comment the code lines")
print("")
# Set LEGACY mode - Azure ML v1 - since private link and DatabricksStep
p.ws.update(v1_legacy_mode=True) # If you happen to have a workspace in v2 mode, and want to change back to v1 legacy mode
# Out:
# {'id': '/subscriptions/ca0a8c40-b06a-4e4e-8434-63c03a1dee34/resourceGroups/abc-def-esml-project002-weu-dev-004-rg/providers/Microsoft.MachineLearningServices/workspaces/aml-prj002-weu-dev-003',
#  'name': 'aml-prj002-weu-dev-003',
#  'identity': {'principal_id': '6b6b2ffa-6896-45af-9538-fa77b7736d7c',
#   'tenant_id': '72f988bf-86f1-41af-91ab-2d7cd011db47',
#   'type': 'SystemAssigned'},
#  'location': 'westeurope',
#  'type': 'Microsoft.MachineLearningServices/workspaces',
#  'tags': {'CostCenter': '007',
#   'UnitCode': 'DC',
#   'Project': 'Batcave upgrade',
#   'Owner': 'joakim.joakim@microsoft.com',
#   'TechnicalContact': 'joakim.joakim@microsoft.com',
#   'Description': 'Optimize bat cave traps, to catch more bad guys. Predict where the Joker will enter etc.',
#   'DatabricksUIPrivate': 'False',
#   'AMLStudioUIPrivate': 'True'},
#  'sku': 'Basic',
#  'workspaceid': 'b80df4f0-e26e-477d-8411-b9052d20276e',
#  'sdkTelemetryAppInsightsKey': '9ac578de-874f-4fea-85bc-7e4cefd0d47f',
#  'description': 'Azure ML workspace for prj002 in ESML-dev environment. In AI Factory(004), in westeurope',
#  'friendlyName': 'prj002-dev-004',
#  'creationTime': '2022-05-03T15:12:03.1217271+00:00',
#  'containerRegistry': '/subscriptions/ca0a8c40-b06a-4e4e-8434-63c03a1dee34/resourceGroups/abc-def-esml-project002-weu-dev-004-rg/providers/Microsoft.ContainerRegistry/registries/acrprj002weufubyjdev003',
#  'keyVault': '/subscriptions/ca0a8c40-b06a-4e4e-8434-63c03a1dee34/resourceGroups/abc-def-esml-project002-weu-dev-004-rg/providers/Microsoft.Keyvault/vaults/kv-p002-weu-dev-fubyj03',
#  'applicationInsights': '/subscriptions/ca0a8c40-b06a-4e4e-8434-63c03a1dee34/resourceGroups/abc-def-esml-project002-weu-dev-004-rg/providers/Microsoft.insights/components/ain-prj002-weu-dev-fubyj-003',
#  'storageAccount': '/subscriptions/ca0a8c40-b06a-4e4e-8434-63c03a1dee34/resourceGroups/abc-def-esml-project002-weu-dev-004-rg/providers/microsoft.storage/storageAccounts/saprj002weufubyj003dev',
#  'hbiWorkspace': False,
#  'allowPublicAccessWhenBehindVnet': True,
#  'provisioningState': 'Succeeded',
#  'imageBuildCompute': 'prj002-m11-dev',
#  'discoveryUrl': 'https://westeurope.api.azureml.ms/discovery',
#  'privateEndpointConnections': [{'id': '/subscriptions/ca0a8c40-b06a-4e4e-8434-63c03a1dee34/resourceGroups/abc-def-esml-project002-weu-dev-004-rg/providers/Microsoft.MachineLearningServices/workspaces/aml-prj002-weu-dev-003/privateEndpointConnections/aml-prj002-weu-dev-003.9baf536e-63e1-4002-b34f-49eb42d5093c',
#    'properties': {'provisioning_state': 'Succeeded',
#     'private_endpoint': {'id': '/subscriptions/ca0a8c40-b06a-4e4e-8434-63c03a1dee34/resourceGroups/abc-def-esml-project002-weu-dev-004-rg/providers/Microsoft.Network/privateEndpoints/pend-prj002-aml-to-vnt-mlcmn'},
#     'privatelink_service_connection_state': {'status': 'Approved',
#      'description': 'Auto-Approved',
#      'actionsRequired': 'None'}}},
#   {'id': '/subscriptions/ca0a8c40-b06a-4e4e-8434-63c03a1dee34/resourceGroups/abc-def-esml-project002-weu-DEV-004-rg/providers/Microsoft.MachineLearningServices/workspaces/aml-prj002-weu-dev-003/privateEndpointConnections/aml-prj002-weu-dev-003.6a7ee185-d9dd-4412-9176-5a11c650cab1',
#    'properties': {'provisioning_state': 'Succeeded',
#     'private_endpoint': {'id': '/subscriptions/ad3ea9e5-14aa-49e4-9016-41de1910df97/resourceGroups/vnet-ad3ea9e5-WestEurope-159-rg/providers/Microsoft.Network/privateEndpoints/adf-prj002-weu-dev-fubyj-003.esml-prj002-aml-dev-pend'},
#     'privatelink_service_connection_state': {'status': 'Approved',
#      'description': 'Requested by DataFactory:adf-prj002-weu-dev-fubyj-003, Name:esml-prj002-aml-dev-pend',
#      'actionsRequired': 'None'}}}],
#  'notebookInfo': {'fqdn': 'ml-aml-prj002-w-westeurope-b80df4f0-e26e-477d-8411-b9052d20276e.westeurope.notebooks.azure.net',
#   'resource_id': 'ef544b200bba4cb0b9bcb6ea3e931b9a'}}

# %% [markdown]
# ## 2a) `DEPLOY`: Option A - Let ESML find BEST Model ( and its environment, scoring script)

# %%
inference_config, model, best_run = IESMLController.get_best_model_inference_config(p.ws, p.model_folder_name, p.ModelAlias)
service,api_uri, kv_aks_api_secret= p.deploy_model_as_private_aks_online_endpoint(model,inference_config,overwrite_endpoint=True)
# Out:
# Searching with Model list LAMBDA FILTER, on experiment_name in Model.tags called: 11_diabetes_model_reg . Meaning ESML checks for both Notebook run (AutoMLRun, Run) and PipelineRuns (AutoMLStep, PipelineRun)
# E.g. Even if Pipeline experiment is called '11_diabetes_model_reg_IN_2_GOLD_TRAIN' it will be included, since original model_folder_name in ESML is '11_diabetes_model_reg' as a notebook Run experiment name. Both is included in search
# Filter search, minutes: 0.2342929244041443
# ESML INFO: try: automl_run or notebook_automl
# Experiment name: 11_diabetes_model_reg
# ws name: aml-prj002-weu-DEV-003
# run_id: 46715da5-4bab-4522-b4ff-744f5bcbef93
#  ## ESML: AutoMLRun?
#  ## ESML: AutoMLRun = TRUE
# INFO: Local scoring script file exists at ../../../01_pipelines/M11/your_code/your_scoring_file_v_1_0_0.py
# Deploying model: AutoML449698ff00 with verison: 15 to environment: dev with overwrite_endpoint=True
# Note: OVERRIDING enterprise performance settings with project specifics. (to change, set flag in 'dev_test_prod_settings.json' -> override_enterprise_settings_with_model_specific=False)
# image_build_compute = p002-m11weu-dev
# Found existing AksWebservice endpoint, deleting it, since overwrite=True
# Note: OVERRIDING enterprise performance settings with project specifics. (to change, set flag in 'dev_test_prod_settings.json' -> override_enterprise_settings_with_model_specific=False)
# Found existing cluster, esml002-weu-dev, using it.
# Note: Autoscale_enabled=False, or since aks_dev_test=True in config, autoscaling is automatically shut off, e.g. overridden in config (since not supported) for environment dev
# Tips: You can try get_logs(): https://aka.ms/debugimage#dockerlog or local deployment: https://aka.ms/debugimage#debug-locally to debug if deployment takes longer than 10 minutes.
# Running
# 2023-01-06 01:06:59+00:00 Creating Container Registry if not exists.
# 2023-01-06 01:07:01+00:00 Use the existing image.
# 2023-01-06 01:07:02+00:00 Creating resources in AKS.
# 2023-01-06 01:07:03+00:00 Submitting deployment to compute.
# 2023-01-06 01:07:03+00:00 Checking the status of deployment esml-dev-p002-m11-aksapi..
# 2023-01-06 01:07:52+00:00 Checking the status of inference endpoint esml-dev-p002-m11-aksapi.
# Succeeded
# AKS service creation operation finished, operation "Succeeded"
# Healthy
# 2023-01-06T01:07:28,168154520+00:00 - rsyslog/run
# 2023-01-06T01:07:28,168707823+00:00 - iot-server/run
# 2023-01-06T01:07:28,171113933+00:00 - nginx/run
# 2023-01-06T01:07:28,178085263+00:00 - gunicorn/run
# 2023-01-06T01:07:28,181086676+00:00 | gunicorn/run |
# 2023-01-06T01:07:28,184274589+00:00 | gunicorn/run | ###############################################
# 2023-01-06T01:07:28,188907509+00:00 | gunicorn/run | AzureML Container Runtime Information
# 2023-01-06T01:07:28,190369115+00:00 | gunicorn/run | ###############################################
# 2023-01-06T01:07:28,191859022+00:00 | gunicorn/run |
# 2023-01-06T01:07:28,193420828+00:00 | gunicorn/run |
# 2023-01-06T01:07:28,198154949+00:00 | gunicorn/run | AzureML image information: openmpi3.1.2-ubuntu18.04, Materializaton Build:20220930.v4
# 2023-01-06T01:07:28,199652355+00:00 | gunicorn/run |
# 2023-01-06T01:07:28,201095661+00:00 | gunicorn/run |
# 2023-01-06T01:07:28,202519067+00:00 | gunicorn/run | PATH environment variable: /azureml-envs/azureml_167ced737ee9811a93e21408b63f0ab3/bin:/opt/miniconda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin
# 2023-01-06T01:07:28,203967374+00:00 | gunicorn/run | PYTHONPATH environment variable:
# 2023-01-06T01:07:28,205416280+00:00 | gunicorn/run |
# 2023-01-06T01:07:28,208425693+00:00 | gunicorn/run | Pip Dependencies (before dynamic installation)
#
# EdgeHubConnectionString and IOTEDGE_IOTHUBHOSTNAME are not set. Exiting...
# 2023-01-06T01:07:28,256508998+00:00 - iot-server/finish 1 0
# 2023-01-06T01:07:28,258027805+00:00 - Exit code 1 is normal. Not restarting iot-server.
# adal==1.2.7
# applicationinsights==0.11.10
# argcomplete==2.0.0
# arviz @ file:///tmp/build/80754af9/arviz_1614019183254/work
# attrs==22.1.0
# azure-common==1.1.28
# azure-core==1.26.0
# azure-graphrbac==0.61.1
# azure-identity==1.11.0
# azure-mgmt-authorization==2.0.0
# azure-mgmt-containerregistry==10.0.0
# azure-mgmt-core==1.3.2
# azure-mgmt-keyvault==10.1.0
# azure-mgmt-resource==21.1.0
# azure-mgmt-storage==20.0.0
# azure-storage-blob==12.13.0
# azure-storage-queue==12.4.0
# azureml-automl-core==1.46.1
# azureml-automl-runtime==1.46.1
# azureml-core==1.46.0
# azureml-dataprep==4.5.7
# azureml-dataprep-native==38.0.0
# azureml-dataprep-rslex==2.11.4
# azureml-dataset-runtime==1.46.0
# azureml-defaults==1.46.0
# azureml-inference-server-http==0.7.6
# azureml-interpret==1.46.0
# azureml-mlflow==1.46.0
# azureml-pipeline-core==1.46.0
# azureml-responsibleai==1.46.0
# azureml-telemetry==1.46.0
# azureml-train-automl-client==1.46.0
# azureml-train-automl-runtime==1.46.1
# azureml-train-core==1.46.0
# azureml-train-restclients-hyperdrive==1.46.0
# azureml-training-tabular==1.46.1
# backcall==0.2.0
# backports.tempfile==1.0
# backports.weakref==1.0.post1
# bcrypt==4.0.0
# bokeh==2.4.3
# boto==2.49.0
# boto3 @ file:///home/conda/feedstock_root/build_artifacts/boto3_1602889982367/work
# botocore @ file:///home/conda/feedstock_root/build_artifacts/botocore_1602884371056/work
# brotlipy==0.7.0
# cachetools==5.2.0
# certifi @ file:///opt/conda/conda-bld/certifi_1655968806487/work/certifi
# cffi @ file:///tmp/abs_98z5h56wf8/croots/recipe/cffi_1659598650955/work
# cftime @ file:///tmp/build/80754af9/cftime_1638345281172/work
# charset-normalizer==2.1.1
# click @ file:///home/linux1/recipes/ci/click_1610990599742/work
# cloudpickle @ file:///Users/ktietz/demo/mc3/conda-bld/cloudpickle_1629142150447/work
# configparser==3.7.4
# contextlib2==21.6.0
# convertdate @ file:///tmp/build/80754af9/convertdate_1634070773133/work
# cryptography @ file:///tmp/build/80754af9/cryptography_1652083456434/work
# cycler @ file:///tmp/build/80754af9/cycler_1637851556182/work
# Cython==0.29.17
# dask==2.30.0
# databricks-cli==0.17.3
# dataclasses==0.6
# debugpy==1.6.3
# decorator==5.1.1
# dice-ml==0.8
# dill==0.3.5.1
# distributed==2.30.1
# distro==1.7.0
# docker==5.0.3
# dotnetcore2==3.1.23
# dowhy==0.7.1
# econml==0.13.1
# entrypoints==0.4
# ephem @ file:///tmp/build/80754af9/ephem_1638960312619/work
# erroranalysis==0.3.11
# fairlearn==0.7.0
# fbprophet @ file:///home/conda/feedstock_root/build_artifacts/fbprophet_1599365534439/work
# fire==0.4.0
# Flask==2.1.3
# Flask-Cors==3.0.10
# flatbuffers==22.9.24
# fonttools==4.25.0
# fsspec==2022.8.2
# gensim==3.8.3
# gitdb==4.0.9
# GitPython==3.1.28
# google-api-core==2.10.2
# google-auth==2.12.0
# googleapis-common-protos==1.56.4
# gunicorn==20.1.0
# h5py==3.7.0
# HeapDict==1.0.1
# holidays @ file:///home/conda/feedstock_root/build_artifacts/holidays_1595448845196/work
# humanfriendly==10.0
# idna @ file:///tmp/build/80754af9/idna_1637925883363/work
# importlib-metadata==4.13.0
# importlib-resources==5.9.0
# inference-schema==1.4.2.1
# interpret-community==0.27.0
# interpret-core==0.2.7
# ipykernel==6.6.0
# ipython==7.34.0
# isodate==0.6.1
# itsdangerous==2.1.2
# jedi==0.18.1
# jeepney==0.8.0
# Jinja2==2.11.2
# jmespath @ file:///Users/ktietz/demo/mc3/conda-bld/jmespath_1630583964805/work
# joblib==0.14.1
# json-logging-py==0.2
# jsonpickle==2.2.0
# jsonschema==4.16.0
# jupyter-client==7.3.5
# jupyter-core==4.11.1
# keras2onnx==1.6.0
# kiwisolver @ file:///opt/conda/conda-bld/kiwisolver_1653292039266/work
# knack==0.9.0
# korean-lunar-calendar @ file:///tmp/build/80754af9/korean_lunar_calendar_1634063020401/work
# lightgbm==3.2.1
# llvmlite==0.38.1
# locket==1.0.0
# LunarCalendar @ file:///tmp/build/80754af9/lunarcalendar_1646383991234/work
# MarkupSafe==2.0.1
# matplotlib @ file:///tmp/build/80754af9/matplotlib-suite_1647441664166/work
# matplotlib-inline==0.1.6
# ml-wrappers==0.2.2
# mlflow-skinny==1.29.0
# mpi4py @ file:///home/conda/feedstock_root/build_artifacts/mpi4py_1660326262210/work
# mpmath==1.2.1
# msal==1.20.0
# msal-extensions==1.0.0
# msgpack==1.0.4
# msrest==0.7.1
# msrestazure==0.6.4
# munkres==1.1.4
# ndg-httpsclient==0.5.1
# nest-asyncio==1.5.6
# netCDF4==1.5.7
# networkx==2.5
# nimbusml==1.8.0
# numba==0.55.2
# numpy @ file:///home/conda/feedstock_root/build_artifacts/numpy_1649806299270/work
# oauthlib==3.2.1
# onnx==1.12.0
# onnxconverter-common==1.6.0
# onnxmltools==1.4.1
# onnxruntime==1.11.1
# opencensus==0.11.0
# opencensus-context==0.1.3
# opencensus-ext-azure==1.1.7
# packaging @ file:///tmp/build/80754af9/packaging_1637314298585/work
# pandas==1.1.5
# paramiko==2.11.0
# parso==0.8.3
# partd==1.3.0
# pathspec==0.10.1
# patsy==0.5.2
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==9.2.0
# pkginfo==1.8.3
# pkgutil-resolve-name==1.3.10
# pmdarima==1.7.1
# portalocker==2.5.1
# prompt-toolkit==3.0.31
# protobuf==3.20.3
# psutil @ file:///opt/conda/conda-bld/psutil_1656431268089/work
# ptyprocess==0.7.0
# py-cpuinfo==5.0.0
# pyarrow==9.0.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycparser @ file:///tmp/build/80754af9/pycparser_1636541352034/work
# pydot==1.4.2
# Pygments==2.13.0
# PyJWT==2.5.0
# PyMeeus @ file:///tmp/build/80754af9/pymeeus_1634069098549/work
# PyNaCl==1.5.0
# pyOpenSSL @ file:///opt/conda/conda-bld/pyopenssl_1643788558760/work
# pyparsing @ file:///tmp/build/80754af9/pyparsing_1635766073266/work
# pyrsistent==0.18.1
# PySocks @ file:///tmp/build/80754af9/pysocks_1594394576006/work
# pystan @ file:///tmp/build/80754af9/pystan_1613565226242/work
# python-dateutil @ file:///tmp/build/80754af9/python-dateutil_1626374649649/work
# pytz @ file:///opt/conda/conda-bld/pytz_1654762638606/work
# PyYAML==6.0
# pyzmq==24.0.1
# raiutils==0.2.0
# requests==2.28.1
# requests-oauthlib==1.3.1
# responsibleai==0.22.0
# rsa==4.9
# s3transfer @ file:///tmp/build/80754af9/s3transfer_1616183147336/work
# scikit-learn==0.22.1
# scipy==1.5.3
# SecretStorage==3.3.3
# semver==2.13.0
# setuptools-git==1.2
# shap==0.39.0
# six @ file:///tmp/build/80754af9/six_1644875935023/work
# skl2onnx==1.4.9
# sklearn-pandas==1.7.0
# slicer==0.0.7
# smart-open==1.9.0
# smmap==5.0.0
# sortedcontainers==2.4.0
# sparse==0.13.0
# sqlparse==0.4.3
# statsmodels==0.11.1
# sympy==1.10.1
# tabulate==0.9.0
# tblib==1.7.0
# termcolor==2.0.1
# toolz==0.12.0
# tornado==6.2
# tqdm @ file:///opt/conda/conda-bld/tqdm_1650891076910/work
# traitlets==5.4.0
# typing-extensions @ file:///tmp/abs_ben9emwtky/croots/recipe/typing_extensions_1659638822008/work
# urllib3 @ file:///tmp/build/80754af9/urllib3_1603305693037/work
# wcwidth==0.2.5
# websocket-client==1.4.1
# Werkzeug==2.2.2
# wrapt==1.12.1
# xarray @ file:///opt/conda/conda-bld/xarray_1639166117697/work
# xgboost==1.3.3
# zict==2.2.0
# zipp==3.8.1
#
# 2023-01-06T01:07:28,700528696+00:00 | gunicorn/run |
# 2023-01-06T01:07:28,702106502+00:00 | gunicorn/run | ###############################################
# 2023-01-06T01:07:28,703633009+00:00 | gunicorn/run | AzureML Inference Server
# 2023-01-06T01:07:28,705297916+00:00 | gunicorn/run | ###############################################
# 2023-01-06T01:07:28,706858023+00:00 | gunicorn/run |
# 2023-01-06T01:07:30,175361659+00:00 | gunicorn/run | Starting AzureML Inference Server HTTP.
#
# Azure ML Inferencing HTTP server v0.7.6
#
#
# Server Settings
# ---------------
# Entry Script Name: /structure/azureml-app/main.py
# Model Directory: /var/azureml-app/azureml-models/AutoML449698ff00/15
# Worker Count: 1
# Worker Timeout (seconds): 300
# Server Port: 31311
# Application Insights Enabled: false
# Application Insights Key: AppInsights key provided
# Inferencing HTTP server version: azmlinfsrv/0.7.6
# CORS for the specified origins: None
#
#
# Server Routes
# ---------------
# Liveness Probe: GET   127.0.0.1:31311/
# Score:          POST  127.0.0.1:31311/score
#
# Starting gunicorn 20.1.0
# Listening at: http://0.0.0.0:31311 (12)
# Using worker: sync
# Booting worker with pid: 69
# Initializing logger
# 2023-01-06 01:07:30,837 | root | INFO | Starting up app insights client
# logging socket was found. logging is available.
# logging socket was found. logging is available.
# 2023-01-06 01:07:30,838 | root | INFO | Starting up app insight hooks
# 2023-01-06 01:07:31,178 | root | INFO | Found driver script at /structure/azureml-app/main.py and the score script at /structure/azureml-app/your_scoring_file_v_1_0_0.py
# 2023-01-06 01:07:31,178 | root | INFO | run() is decorated with @input_schema. Server will invoke it with the following arguments: data.
# 2023-01-06 01:07:31,178 | root | INFO | Invoking user's init function
# generated new fontManager
# Importing plotly failed. Interactive plots will not work.
# 2023-01-06 01:07:35,380 | azureml.core | WARNING | Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (azure-identity 1.11.0 (/azureml-envs/azureml_167ced737ee9811a93e21408b63f0ab3/lib/python3.7/site-packages), Requirement.parse('azure-identity==1.7.0'), {'azureml-dataprep'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (azure-identity 1.11.0 (/azureml-envs/azureml_167ced737ee9811a93e21408b63f0ab3/lib/python3.7/site-packages), Requirement.parse('azure-identity==1.7.0'), {'azureml-dataprep'}).
# 2023-01-06 01:07:35,516 | azureml.core | WARNING | Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception The 'types-cryptography>=3.3.21; extra == "crypto"' distribution was not found and is required by PyJWT.
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception The 'types-cryptography>=3.3.21; extra == "crypto"' distribution was not found and is required by PyJWT.
# 2023-01-06 01:07:35,570 | azureml.core | WARNING | Failure while loading azureml_run_type_providers. Failed to load entrypoint hyperdrive = azureml.train.hyperdrive:HyperDriveRun._from_run_dto with exception The 'types-cryptography>=3.3.21; extra == "crypto"' distribution was not found and is required by PyJWT.
# Failure while loading azureml_run_type_providers. Failed to load entrypoint hyperdrive = azureml.train.hyperdrive:HyperDriveRun._from_run_dto with exception The 'types-cryptography>=3.3.21; extra == "crypto"' distribution was not found and is required by PyJWT.
# 2023-01-06 01:07:35,623 | azureml.core | WARNING | Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.PipelineRun = azureml.pipeline.core.run:PipelineRun._from_dto with exception The 'types-cryptography>=3.3.21; extra == "crypto"' distribution was not found and is required by PyJWT.
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.PipelineRun = azureml.pipeline.core.run:PipelineRun._from_dto with exception The 'types-cryptography>=3.3.21; extra == "crypto"' distribution was not found and is required by PyJWT.
# 2023-01-06 01:07:35,676 | azureml.core | WARNING | Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.ReusedStepRun = azureml.pipeline.core.run:StepRun._from_reused_dto with exception The 'types-cryptography>=3.3.21; extra == "crypto"' distribution was not found and is required by PyJWT.
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.ReusedStepRun = azureml.pipeline.core.run:StepRun._from_reused_dto with exception The 'types-cryptography>=3.3.21; extra == "crypto"' distribution was not found and is required by PyJWT.
# 2023-01-06 01:07:35,728 | azureml.core | WARNING | Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.StepRun = azureml.pipeline.core.run:StepRun._from_dto with exception The 'types-cryptography>=3.3.21; extra == "crypto"' distribution was not found and is required by PyJWT.
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.StepRun = azureml.pipeline.core.run:StepRun._from_dto with exception The 'types-cryptography>=3.3.21; extra == "crypto"' distribution was not found and is required by PyJWT.
# 00000000-0000-0000-0000-000000000000,01:Trying to deserialize model with name with model.pkl. 01=SUCCESS
# 01:Trying to deserialize model with name with model.pkl. 01=SUCCESS
# 2023-01-06 01:07:36,421 | root | INFO | Users's init has completed successfully
# 2023-01-06 01:07:36,421 | root | INFO | Swaggers are prepared for the following versions: [2, 3].
# 2023-01-06 01:07:36,421 | root | INFO | Scoring timeout is found from os.environ: 300000 ms
# 2023-01-06 01:07:36,422 | root | INFO | AML_FLASK_ONE_COMPATIBILITY is set. Patched Flask to ensure compatibility with Flask 1.
# 2023-01-06 01:07:53,208 | root | INFO | 200
# 127.0.0.1 - - [06/Jan/2023:01:07:53 +0000] "GET /swagger.json HTTP/1.0" 200 3264 "-" "curl/7.80.0"
# 2023-01-06 01:07:57,810 | root | INFO | 200
# 127.0.0.1 - - [06/Jan/2023:01:07:57 +0000] "GET /swagger.json HTTP/1.0" 200 3264 "-" "curl/7.80.0"
#
# Deployed AKS Webservice: esml-dev-p002-m11-aksapi
# Webservice Uri: http://10.11.22.34:80/api/v1/service/esml-dev-p002-m11-aksapi/score
# Webservice API_Secret are stored in keyvault with name: esml-dev-p002-m11-apisecret
# Webservice API_URI are stored in keyvault with name: esml-dev-p002-m11-api
# Webservice Swagger Uri: http://10.11.22.34:80/api/v1/service/esml-dev-p002-m11-aksapi/swagger.json

# %% [markdown]
# ## 2b) `DEPLOY`: Option B - Inject YOUR selection of model and run, any model, override "ESML best model logic"

# %% [markdown]
# #### Option B (Model A): ...Deploy ANY model (not only the best promoted model)

# %%
model_name = 'your_model_folder_name' # '11_diabetes_model_reg' - Find a model name in Azure ML Studio/Model register or lake_settings.json
model_version = 1 # Find a model name in Azure ML Studio/Model register
run_id = 'todo_c70-3ef4-470c-9f55-92b33318c8ad'# '9360ac70-3ef4-470c-9f55-92b33318c8ad' # Main pipeline run - Find a model name in Azure ML Studio/Model register

inference_config, model, best_run = IESMLController.get_any_model_inference_config(p.ws, p.model_folder_name, p.ModelAlias, model_name,model_version,run_id)
service,api_uri, kv_aks_api_secret= p.deploy_model_as_private_aks_online_endpoint(model,inference_config,overwrite_endpoint=True)

# %% [markdown]
# # 3) `Smoke testing:` TEST ENDPOINT - Score with some test data

# %% [markdown]
# ### Get testdata, and score it

# %%
p.connect_to_lake()
X_test, y_test, tags = p.get_gold_validate_Xy()
caller_id = "10965d9c-40ca-4e47-9723-5a608a32a0e4" # Pass an optional tracking ID for the request, parquet file will then have this name

df = p.call_webservice(p.ws, X_test,caller_id) # Saves to datalake also
#df = p.call_webservice(ws=p.ws, pandas_X_test=X_test.iloc[:1],user_id=caller_id,firstRowOnly=True,save_2_lake_also=False) # If only 1 row, and not saving result to datalake
pd.set_option('display.max_colwidth', None)
df.head()
# Out:
# Using GEN2 as Datastore
# use_project_sp_2_mount: True
# Searching for setting in ESML datalake...
# ESML in-folder settings override = TRUE
#  - Found settings in the ESML AutoLake  [active_in_folder.json,active_scoring_in_folder.json], to override ArgParse/GIT config with.
#  - TRAIN in date:  2021/01/01
#  - INFERENCE in date: 2021/06/08 and ModelVersion to score with: 1 (0=latest)
# M11_GOLD_VALIDATE : (168, 11)
# X_test  (168, 10)
# y_test  (168,)
# Note: OVERRIDING enterprise performance settings with project specifics. (to change, set flag in 'dev_test_prod_settings.json' -> override_enterprise_settings_with_model_specific=False)
# Note: Fetching keys automatically via workspace keyvault.
# Saving scoring to lake for project folder project002 and inference_model_version: 15 ...
#
# Saved DATA to score successfully in LAKE, as file 'to_score_10965d9c-40ca-4e47-9723-5a608a32a0e4.parquet'
# Saved SCORED data in LAKE, as file 'scored_10965d9c-40ca-4e47-9723-5a608a32a0e4.parquet'
#     AGE   SEX   BMI    BP    S1    S2    S3    S4    S5    S6  result  \
# 0 -0.10  0.05 -0.02 -0.02 -0.09 -0.07 -0.02 -0.04 -0.08 -0.07   93.92
# 1 -0.10 -0.04 -0.08  0.01 -0.10 -0.09 -0.01 -0.08 -0.06 -0.03   92.31
# 2 -0.09 -0.04 -0.04 -0.02 -0.07 -0.08  0.04 -0.08 -0.04 -0.10  111.76
# 3 -0.09 -0.04  0.02 -0.03  0.01  0.02 -0.00 -0.00 -0.02  0.00  205.47
# 4 -0.07 -0.04 -0.02 -0.01 -0.02 -0.01  0.02 -0.04 -0.04 -0.03  138.64
#
#    probability  \
# 0          nan
# 1          nan
# 2          nan
# 3          nan
# 4          nan
#
#                                                              esml_info
# 0  01:Trying to deserialize model with name with model.pkl. 01=SUCCESS
# 1  01:Trying to deserialize model with name with model.pkl. 01=SUCCESS
# 2  01:Trying to deserialize model with name with model.pkl. 01=SUCCESS
# 3  01:Trying to deserialize model with name with model.pkl. 01=SUCCESS
# 4  01:Trying to deserialize model with name with model.pkl. 01=SUCCESS

# %% [markdown]
# ## END) `SUMMARY - what did the notebook do:DEPLOY & SERVE: Fetched the BEST MODEL, and deploys on AKS`
# - ESML saves `API_key in Azure keyvault automatically`
# - ESML auto-config solves 4 common 'errors/things': `correct compute name` and `valid replicas, valid agents, valid auto scaling` in
#     -  AKS_SETTINGS: [aks_config_dev.json](../settings/project_specific/model/dev_test_prod_override/online/aks_config_dev.json)
# - Tip 1: You can adjust the number of replicas, and different CPU/memory configuration, or using a different compute target.
#
# ### Logging: enable in [aks_config_dev.json](../settings/project_specific/model/dev_test_prod_override/online/aks_config_dev.json)
# You can enable logging with LogAnalytics, with the flags
#
#     `enable_app_insights:true`
#     `collect_model_data:true`
#
# ### AKS_SETTINGS
# - Here you can edit AKS settings (performance for DEV, TEST, PROD environments) under PROJECT specific MODEL settings and ONLINE = AKS
#     -  Link: [aks_config_dev.json](../settings/project_specific/model/dev_test_prod_override/online/aks_config_dev.json)
# - Note:
#     - Q: Why is `docker_bridge_cidr` a PUBLIC IP? Isn't this a PRIVATE AKS cluster?
#     - A: Yes, it is PRIVATE. We don’t use the docker bridge for pod communication, but as Docker is configured as part of the Kubernetes setup, this docker bridge it also gets created as well, so in order to avoid that it picks random unknown CIDR that could collide with any of your existent subnets, we give the option to change it and set it a known range. So the indication for docker bridge is to define any CIDR that doesn’t to Azure, and doesn’t collide with any other subnet.
#         - Read more: [learn.microsoft.com](https://learn.microsoft.com/en-us/answers/questions/199786/how-to-update-docker-bridge-cidr-for-aks-to-a-diff.html)

# %% [markdown]
# # END
